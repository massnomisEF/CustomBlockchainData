# %%
import plotly.express as px
import pandas as pd

# %%
# Select 
#    date_trunc('day', block_timestamp) as day,
#    avg(fee_usd) as Avg_Fee_Usd, 
#    median(fee_usd) as Median_Fee_Usd, 
#    sum(fee_usd) as Total_Fees, 
#    count(tx_id) as Total_Transactions
# from polygon.transactions 
#    group by day 
#    order by day desc
df = pd.read_csv('POLY_DATA.csv')  
df.head()
# Out:
#                        DAY  AVG_FEE_USD  MEDIAN_FEE_USD    TOTAL_FEES  \
# 0  2022-03-30 00:00:00.000     0.015980        0.007753  21239.020254
# 1  2022-03-29 00:00:00.000     0.017506        0.006688  53823.126667
# 2  2022-03-28 00:00:00.000     0.016405        0.007236  51203.906979
# 3  2022-03-27 00:00:00.000     0.016071        0.007591  45023.446365
# 4  2022-03-26 00:00:00.000     0.016287        0.007029  42148.273600
#
#    TOTAL_TRANSACTIONS
# 0             1329069
# 1             3074508
# 2             3121239
# 3             2801619
# 4             2587822

# %%
fig = px.line(
    df, 
    x = "DAY",
    y = ["AVG_FEE_USD","MEDIAN_FEE_USD"]
)
fig.show()

# %%
fig = px.line(
    df, 
    x = "DAY",
    y = "TOTAL_FEES"
)
fig.show()

# %%
fig = px.line(
    df, 
    x = "DAY",
    y = "TOTAL_TRANSACTIONS"
)
fig.show()

# %%
# Select 
#    date_trunc('day', block_timestamp) as day,
#    avg(fee_usd) as Avg_Fee_Usd, 
#    median(fee_usd) as Median_Fee_Usd, 
#    sum(fee_usd) as Total_Fees, 
#    count(tx_id) as Total_Transactions
# from ethereum.transactions 
#    group by day 
#    order by day desc
df = pd.read_csv('ETH_DATA.csv')  
df.head()
# Out:
#                        DAY  AVG_FEE_USD  MEDIAN_FEE_USD    TOTAL_FEES  \
# 0  2022-03-30 00:00:00.000    10.982264        4.896895  6.813045e+06
# 1  2022-03-29 00:00:00.000    14.264490        6.281288  1.711595e+07
# 2  2022-03-28 00:00:00.000    26.177481        6.802881  3.188383e+07
# 3  2022-03-27 00:00:00.000    17.517202        4.330909  1.966612e+07
# 4  2022-03-26 00:00:00.000     9.319485        4.037367  1.047368e+07
#
#    TOTAL_TRANSACTIONS
# 0              620368
# 1             1199899
# 2             1217987
# 3             1122675
# 4             1123847

# %%
fig = px.line(
    df, 
    x = "DAY",
    y = ["AVG_FEE_USD","MEDIAN_FEE_USD"]
)
fig.show()

# %%
fig = px.line(
    df, 
    x = "DAY",
    y = "TOTAL_FEES"
)
fig.show()

# %%
fig = px.line(
    df, 
    x = "DAY",
    y = "TOTAL_TRANSACTIONS"
)
fig.show()
